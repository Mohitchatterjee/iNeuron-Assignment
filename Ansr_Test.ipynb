# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohitchatterjee/iNeuron-Assignment/blob/main/Ansr_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. You have been given a dataset named sales_data.csv that contains information about sales transactions. The dataset has columns date, product_id, quantity, and revenue. Write a Python script to read the dataset, manipulate the data to calculate the total revenue for each product, and then create a bar plot to visualize the top 10 products by revenue.

# %%
import pandas as pd

# %%
sales_data = [['2023-07-01',1001,10,100],
['2023-07-01',1002,5,75],
['2023-07-02',1001,8,80],
['2023-07-02',1003,3,45],
['2023-07-03',1002,12,180],
['2023-07-03',1003,6,90],
['2023-07-04',1001,15,150],
['2023-07-04',1002,7,105],
['2023-07-04',1003,9,135]]

df = pd.DataFrame(sales_data, columns=['date','product_id','quantity','revenue'])
df
# Out:
#          date  product_id  quantity  revenue
# 0  2023-07-01        1001        10      100
# 1  2023-07-01        1002         5       75
# 2  2023-07-02        1001         8       80
# 3  2023-07-02        1003         3       45
# 4  2023-07-03        1002        12      180
# 5  2023-07-03        1003         6       90
# 6  2023-07-04        1001        15      150
# 7  2023-07-04        1002         7      105
# 8  2023-07-04        1003         9      135

# %%
emptyDict = {}
for i in df.values:
  if i[1] not in emptyDict:emptyDict[i[1]] =  i[3]
  else:emptyDict[i[1]] = emptyDict[i[1]]+i[3]

# %%
print('Total Revenue of each product', emptyDict)
# Out:
# Total Revenue of each product {1001: 330, 1002: 360, 1003: 270}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(list(emptyDict.keys()))
y = np.array(list(emptyDict.values()))
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# **2 Context:** Say we have a table `salaries` with data on employee salary and department in the following format:
#
# depname | empno | salary |
#
# -----------+-------+--------+
#
# develop | 11 | 5200 |
#
# develop | 7 | 4200 |
#
# develop | 9 | 4500 |
#
# develop | 8 | 6000 |
#
# develop | 10 | 5200 |
#
# personnel | 5 | 3500 |
#
# personnel | 2 | 3900 |
#
# sales | 3 | 4800 |
#
# sales | 1 | 5000 |
#
# sales | 4 | 4800 |
#
# Task: Write a query to get the `empno` with the highest salary

# %% [markdown]
# **SELECT EMPNO FROM SALRIES WHERE salary = (SELECT MAX(salary) FROM SALARIES);**

# %% [markdown]
# 3. You have a dataset named stock_prices.csv that contains daily stock prices of a company. The dataset has columns date and closing_price. Write a Python script to read the dataset, convert the date column to a datetime object, and then perform a time series analysis by plotting the closing price over time with a rolling 30-day moving average

# %%
stock_price_data = [['2023-07-01',150],
['2023-07-02',152.5],
['2023-07-03',155.2],
['2023-07-04',157.9],
['2023-07-05',159.8],
['2023-07-06',161.3],
['2023-07-07',163.1],
['2023-07-08',165],
['2023-07-09',168.2],
['2023-07-10',170.5],
['2023-07-11',172.8],
['2023-07-12',173.5],
['2023-07-13',171.9],
['2023-07-14',170],
['2023-07-15',172.4],
['2023-07-16',173.6],
['2023-07-17',175],
['2023-07-18',176.3],
['2023-07-19',178.2],
['2023-07-20',179.8],
['2023-07-21',180.5]]

# %%
df = pd.DataFrame(stock_price_data,columns=['date','closing_price'])

# %%
df
# Out:
#           date  closing_price
# 0   2023-07-01          150.0
# 1   2023-07-02          152.5
# 2   2023-07-03          155.2
# 3   2023-07-04          157.9
# 4   2023-07-05          159.8
# 5   2023-07-06          161.3
# 6   2023-07-07          163.1
# 7   2023-07-08          165.0
# 8   2023-07-09          168.2
# 9   2023-07-10          170.5
# 10  2023-07-11          172.8
# 11  2023-07-12          173.5
# 12  2023-07-13          171.9
# 13  2023-07-14          170.0
# 14  2023-07-15          172.4
# 15  2023-07-16          173.6
# 16  2023-07-17          175.0
# 17  2023-07-18          176.3
# 18  2023-07-19          178.2
# 19  2023-07-20          179.8
# 20  2023-07-21          180.5

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
df.sort_values(by='date', inplace=True)

# Calculate the 30-day moving average
df['30_day_ma'] = df['closing_price'].rolling(window=30).mean()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['closing_price'], label='Closing Price')
plt.plot(df['date'], df['30_day_ma'], label='30-Day Moving Avg')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices and 30-Day Moving Average')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 4. You have a table named user_activity that contains information about user activity on a website. The table has columns user_id, activity_date, and activity_type. The activity_type can be either 'login', 'click', or 'purchase'. Write an SQL query to find the daily engagement rate, which is the percentage of users who performed at least one activity on a given day out of the total number of distinct users on that day. Round the result to two decimal places.

# %% [markdown]
# SELECT
#     activity_date,
#     ROUND(
#         COUNT(DISTINCT CASE WHEN activity_type IS NOT NULL THEN user_id END) /
#         COUNT(DISTINCT user_id) * 100,
#         2
#     ) AS engagement_rate
# FROM user_activity
# GROUP BY activity_date;

# %% [markdown]
# 5. You have a dataset named customer_data.csv that contains information about customers. The dataset has columns customer_id, age, gender, email, and purchases. Write a Python script to read the dataset, perform data cleaning by removing duplicates and handling missing values, and then calculate the average number of purchases for each gender.

# %%
customer_data = [[1001,35,'M','abc@example.com',10],
[1002,28,'F','def@example.com',5],
[1003,40,'F','ghi@example.com',],
[1004,45,'M','jkl@example.com',8],
[1005,33,'M','mno@example.com',15],
[1006,27,'F','pqr@example.com',],
[1007,50,'M','stu@example.com',12],
[1008,29,'F','vwx@example.com',7],
[1009,38,'F','yza@example.com',9]]

# %%
df = pd.DataFrame(customer_data, columns=['customer_id','age','gender','email','purchases'])

# %%
df
# Out:
#    customer_id  age gender            email  purchases
# 0         1001   35      M  abc@example.com       10.0
# 1         1002   28      F  def@example.com        5.0
# 2         1003   40      F  ghi@example.com        NaN
# 3         1004   45      M  jkl@example.com        8.0
# 4         1005   33      M  mno@example.com       15.0
# 5         1006   27      F  pqr@example.com        NaN
# 6         1007   50      M  stu@example.com       12.0
# 7         1008   29      F  vwx@example.com        7.0
# 8         1009   38      F  yza@example.com        9.0

# %%
df['purchases'].isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# Name: purchases, dtype: bool

# %%
df['purchases'].fillna(method='bfill',inplace=True)

# %%
df
# Out:
#    customer_id  age gender            email  purchases
# 0         1001   35      M  abc@example.com       10.0
# 1         1002   28      F  def@example.com        5.0
# 2         1003   40      F  ghi@example.com        8.0
# 3         1004   45      M  jkl@example.com        8.0
# 4         1005   33      M  mno@example.com       15.0
# 5         1006   27      F  pqr@example.com       12.0
# 6         1007   50      M  stu@example.com       12.0
# 7         1008   29      F  vwx@example.com        7.0
# 8         1009   38      F  yza@example.com        9.0

# %%
sumOfMale,countOfMen,sumOfFemale,countOfFemale= 0,0,0,0
for i in df.values:
  if i[2] == 'M':
    sumOfMale += int(i[4])
    countOfMen+=1
  else:
    sumOfFemale += int(i[4])
    countOfFemale+=1

print('Average Purchase of Male :',sumOfMale/countOfMen)
print('Average Purchase of Female :',sumOfFemale/countOfFemale)
# Out:
# Average Purchase of Male : 11.25
# Average Purchase of Female : 8.2

# %% [markdown]
# 6. You have a table named inventory that contains information about product inventory levels. The table has columns product_id, warehouse_id, date, and quantity. Write an SQL query to find the total quantity of each product in each warehouse for the latest available date.

# %% [markdown]
# SELECT
#     product_id,
#     warehouse_id,
#     MAX(date) AS latest_date,
#     SUM(quantity) AS total_quantity
# FROM inventory
# GROUP BY product_id, warehouse_id;

# %% [markdown]
# 15.  Describe a data project you worked on recently

# %% [markdown]
# Project Phases and Key Components:
#
# 1. Assessment and Requirements Gathering:
#
# Understand the current state of data infrastructure, including data sources, storage, and processing.
# Identify pain points, data quality issues, and performance bottlenecks.
# Collaborate with stakeholders to gather requirements for modernization.
#
# 2. Data Source Integration:
#
# Connect and integrate various data sources (e.g., databases, files, external APIs) into a centralized data repository.
# Use Python to build connectors and data extraction scripts.
#
# 3. Data Cleaning and Transformation:
#
# Utilize Python for data cleaning, transformation, and enrichment.
# Apply PySpark for large-scale data processing, handling, and transformation tasks.
# Implement data quality checks and validation routines.
#
# 4. Data Pipeline Development:
#
# Design a data pipeline using tools like Apache Airflow or custom Python scripts.
# The pipeline should automate data extraction, transformation, and loading (ETL) processes.
# Monitor and manage data pipeline health and performance.
#
# 5. Data Storage and Warehousing:
#
# Choose an appropriate data storage solution (e.g., data warehouse, data lake) that aligns with the organization's needs.
# Optimize data storage for quick retrieval and analysis.
#
# 6. Data Governance and Security:
#
# Implement data governance policies and access controls.
# Ensure compliance with data privacy regulations.
# Use Python for encryption and security measures.
#
# 7. Data Visualization and Reporting:
#
# Develop interactive dashboards and reports using visualization libraries like Matplotlib, Seaborn, or Plotly in Python.
# Enable end-users to explore and analyze data effortlessly.
#
# 8. Performance Optimization:
#
# Fine-tune data pipelines and data processing tasks for improved performance.
# Use PySpark for distributed computing to handle big data workloads efficiently.
